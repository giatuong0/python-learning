# %%
FN = "Darius-13-100m-Fly.txt"

# %%
FOLDER = "swimdata/"

# %%
with open (FOLDER + FN) as file:
    lines = file.readlines()

# %%
type(lines)
# Out:
# list

# %%
lines
# Out:
# ['1:27.95,1:21.07,1:30.96,1:23.22,1:27.95,1:28.30\n']

# %%
lines[0]
# Out:
# '1:27.95,1:21.07,1:30.96,1:23.22,1:27.95,1:28.30\n'

# %%
type(lines[0])
# Out:
# str

# %%
lines[0].strip().split(",")
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
times = lines[0].strip().split(",")

# %%
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
# Star with the string.
first = times[0]

# Extract the component parts: start with the minutes value.
minutes, rest = first.split(":")
#extract the seconds and hundredths values.
seconds, hundredths = rest.split(".")

# Convert THE STRINGS TO NUMBERS WITH THE HLEP OF ANOTHER BIF CALLED
# "int", then perform the calculation.
converted_time = (int(minutes) * 60 * 100) + (int(seconds) * 100) + int(hundredths) 

# Display the result.
print(converted_time)
# Out:
# 8795

# %%
len(times)
# Out:
# 6

# %%
for t in times:
    minutes, rest = t.split(":")
    seconds, hundredths = rest.split(".")
    print(t, "->", (int(minutes) * 60 * 100) + (int(seconds) * 100) + int(hundredths))
# Out:
# 1:27.95 -> 8795
# 1:21.07 -> 8107
# 1:30.96 -> 9096
# 1:23.22 -> 8322
# 1:27.95 -> 8795
# 1:28.30 -> 8830

# %%
converts = []
for t in times:
    minutes, rest = t.split(":")
    seconds, hundredths = rest.split(".")
    converts.append((int(minutes) * 60 * 100) + (int(seconds) * 100) + int(hundredths))

# %%
times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
converts
# Out:
# [8795, 8107, 9096, 8322, 8795, 8830]

# %%
import statistics

# %%
statistics.mean(converts)
# Out:
# 8657.5

# %%
average = statistics.mean(converts)

# %%
average / 100
# Out:
# 86.575

# %%
round(average / 100, 2)
# Out:
# 86.58

# %%
str(round(average / 100, 2)).split(".")
# Out:
# ['86', '58']

# %%
mins_secs, hundredths = str(round(average / 100, 2)).split(".")

# %%
mins_secs = int(mins_secs)

# %%
minutes = mins_secs // 60

# %%
minutes
# Out:
# 1

# %%
seconds = mins_secs - minutes * 60  #minutes is 1 so needed to "*60" to get the seconds value.

# %%
seconds
# Out:
# 26

# %%
minutes, seconds, hundredths
# Out:
# (1, 26, '58')

# %%
str(minutes) + ":" + str(seconds) + "." + hundredths
# Out:
# '1:26.58'

# %%
average = str(minutes) + ":" + str(seconds) + "." + hundredths

# %%
average
# Out:
# '1:26.58'
